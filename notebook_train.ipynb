# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /home/aryan/miniconda3
# datasci                  /home/aryan/miniconda3/envs/datasci
# gym_env                  /home/aryan/miniconda3/envs/gym_env
# speed                 *  /home/aryan/miniconda3/envs/speed

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /miniconda/miniconda3/envs/speed/lib/python3.10/site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: thop, torchvision

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cu118'

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %%
import torch
torch.cuda.empty_cache()

# %%
# !export PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:128

# %%
#TRAINING

# %%
# !python yolov9/train_dual.py --workers 8 --batch 2 --img 640 --epochs 100 --data yolov9/data/coco.yaml --weights yolov9-c.pt --device 0 --cfg yolov9/models/detect/yolov9-c.yaml --hyp yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# train_dual: weights=yolov9-c.pt, cfg=yolov9/models/detect/yolov9-c.yaml, data=yolov9/data/coco.yaml, hyp=yolov9/data/hyps/hyp.scratch-high.yaml, epochs=100, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov9/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.11 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
#
# ...

# %%
#PREDICTIONS

# %%
# !python yolov9/detect.py --conf 0.2 --device 0 --weights yolov9/runs/train/exp10/weights/best.pt --source /home/aryan/Downloads/document_6251075430447582466.mp4
# Out:
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteDownloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Completedetect: weights=['yolov9/runs/train/exp10/weights/best.pt'], source=/home/aryan/Downloads/document_6251075430447582466.mp4, data=yolov9/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov9/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.11 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
#
# Fusing layers...
# ...
